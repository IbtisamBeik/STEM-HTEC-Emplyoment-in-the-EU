# %% [markdown]
# # Employment in the HTEC/STEM sector (Germany)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Total Employment in STEM (in thousands): 
df=pd.read_excel("C:\\Users\\ibsi\\Desktop\\STEM-HTEC-Emplyoment-in-the-EU\\Datasets\\Employment in HTEC.xlsx", sheet_name="HTEC(thousands)")
df=df.drop(df.index[0:4]).reset_index(drop = True)
df.head(5)
# Out:
#     Country    2010    2011    2012    2013    2014    2015    2016    2017  \
# 0   Belgium   211.2   207.8   213.3   198.4   198.6   198.6   196.7   211.3
# 1  Bulgaria    93.3    90.9    93.8    98.8    97.0   112.8   116.1   114.8
# 2   Czechia   209.4   221.2   215.0   226.9   238.2   229.2   242.0   243.6
# 3   Denmark   144.6   145.6   144.8   145.6   149.5   154.5   154.0   143.5
# 4   Germany  1627.8  1662.2  1687.8  1633.7  1648.4  1627.7  1670.4  1703.7
#
#      2018    2019
# 0   230.5   245.1
# 1   122.6   127.7
# 2   261.9   257.7
# 3   146.8   157.3
# 4  1738.2  1759.0

# %%
#Employment with less than a Secondary education:
df1=pd.read_excel("C:\\Users\\ibsi\\Desktop\\STEM-HTEC-Emplyoment-in-the-EU\\Datasets\\Employment in HTEC.xlsx", sheet_name="<Secondary(%)")
df1=df1.drop(df.index[0:4]).reset_index(drop = True)
df1.head(5)
# Out:
#     Country 2010  2011  2012  2013 2014 2015 2016 2017 2018 2019
# 0   Belgium  7.1   6.7   4.6   5.7  5.4  5.1  5.2  4.7  4.2  3.5
# 1  Bulgaria    :     :     :     :    :    :    :    :    :  2.3
# 2   Czechia  2.4   2.3   3.1   1.9    1  2.1  1.9    2  1.9    2
# 3   Denmark   13  12.6  12.6  10.3  9.8   10  9.5  8.5  8.4  8.3
# 4   Germany  6.2   5.8   5.9   6.1  5.9  5.6  5.4  5.2  5.2  5.1

# %%
#Employment with less than a Tertiary education:
df2=pd.read_excel("C:\\Users\\ibsi\\Desktop\\STEM-HTEC-Emplyoment-in-the-EU\\Datasets\\Employment in HTEC.xlsx", sheet_name="<Tertiary(%)")
df2=df2.drop(df.index[0:4]).reset_index(drop = True)
df2.head(5)
# Out:
#     Country  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 0   Belgium  24.7  24.5  23.8  24.8  23.5  23.2  21.3  19.4  22.2  22.7
# 1  Bulgaria  45.3  45.3  46.3  42.4  37.5  37.8  35.5  34.7  34.0  34.6
# 2   Czechia  59.8  58.1  59.6  56.0  52.2  48.7  48.9  46.1  48.9  48.9
# 3   Denmark  38.2  36.1  34.0  34.5  36.6  34.9  34.2  30.0  30.0  31.0
# 4   Germany  48.7  48.3  47.6  47.3  47.3  46.2  45.0  45.3  45.2  44.5

# %%
#Employment with a Tertiary education:
df3=pd.read_excel("C:\\Users\\ibsi\\Desktop\\STEM-HTEC-Emplyoment-in-the-EU\\Datasets\\Employment in HTEC.xlsx", sheet_name="Tertiary(%)")
df3=df3.drop(df.index[0:4]).reset_index(drop = True)
df3.head(5)
# Out:
#                                  Country  2010  2011  2012  2013  2014  2015  \
# 0  Euro area - 19 countries  (from 2015)  52.8  53.8  55.3  55.6  57.2  58.8
# 1                                Belgium  68.1  68.8  71.5  69.5  71.0  71.7
# 2                               Bulgaria  52.1  52.0  51.0  56.0  61.8  61.8
# 3                                Czechia  37.7  39.6  37.4  42.0  46.8  49.2
# 4                                Denmark    47  49.8  51.1  51.9  52.7  54.6
#
#    2016  2017  2018  2019
# 0  59.8  60.7  60.8  62.0
# 1  73.5  75.9  73.6  73.8
# 2  63.6  64.0  64.6  63.1
# 3  49.2  51.9  49.2  49.1
# 4  54.2  59.2  60.1  59.0

# %%
# Stacked bar for Germany:


df1=df1.loc[df1["Country"] == "Germany"]
df2=df2.loc[df2["Country"] == "Germany"]
df3=df3.loc[df3["Country"] == "Germany"]
#frames = [df, df1, df2,df3]
frames = [df1, df2,df3]
result = pd.concat(frames)
del result["Country"]
df = pd.DataFrame(data=result)
df=df.reset_index(drop=True)
df
# Out:
#    2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 0   6.2   5.8   5.9   6.1   5.9   5.6   5.4   5.2   5.2   5.1
# 1  48.7  48.3  47.6  47.3  47.3  46.2    45  45.3  45.2  44.5
# 2    45  45.7  46.4  46.5  46.7    48  49.5  49.5  49.5  50.2

# %%
df_transposed = df.T
df_transposed = df_transposed.rename(columns={0: "<Secondary", 1: "<Tertiary", 2: "Tertiary"})

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
my_colors=["SteelBlue", "LightSteelBlue", "LightGray"]
df_transposed.plot.bar(stacked=True, color =my_colors, ax=ax)
plt.xlabel('Year', fontsize=10)
plt.ylabel('Education level (in %)', fontsize=15)
plt.title("Germany", fontsize=20)
plt.savefig("C:\\Users\\ibsi\\Desktop\\Figure_4", transparent=True, bbox_inches="tight")
